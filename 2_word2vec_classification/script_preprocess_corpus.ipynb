# %% [markdown]
# ## Changelog/Notes
#
# 6/3/2024
# - File created
# - based on script_2_3_text_classifiy_w2v.py by Shin-Han Shiu.

# %% [markdown]
# #### **Goal:** To create w2v classification model for distinguishing evolutionary biology journals (*or any given corpus of journals*) from non evolutionary biology journals

# %%
import pandas as pd

# %% [markdown]
# Modifying corpus to run on original text_classify script

# %%
text = pd.read_csv("/mnt/scratch/ande2472/model_output/evo_bio_class/evo_filtered_data.tsv", sep='\t')

# %%
# Out:
#        Unnamed: 0  index      PMID        Date  \
# 0             769   1515      1538  1975-11-04
# 1             770   1516      1539  1975-11-04
# 2             771   1517      1540  1975-11-04
# 3             772   1518      1541  1975-12-29
# 4             773   1519      1542  1975-12-29
# ...           ...    ...       ...         ...
# 51277    23493572   6961  36471809  2022-12-07
# 51278    23494095   7521  36472372  2022-12-07
# 51279    23494220   7658  36472514  2022-12-07
# 51280    23494226   7673  36472530  2022-12-07
# 51281    23494227   7674  36472532  2022-12-07
#
#                                Journal  \
# 0       Journal of molecular evolution
# 1       Journal of molecular evolution
# 2       Journal of molecular evolution
# 3       Journal of molecular evolution
# 4       Journal of molecular evolution
# ...                                ...
# 51277             Evolutionary ecology
# 51278               Systematic biology
# 51279  Molecular biology and evolution
# 51280  Molecular biology and evolution
# 51281  Molecular biology and evolution
#
#                                                    Title  \
# 0      Prebiotic peptide-formation in the solid state...
# 1      Prebiotic peptide-formation in the solid state...
# 2      The prebiotic synthesis of deoxthymidine oligo...
# 3      Formation of nucleoside 5'-polyphosphates from...
# 4      On the possible role of organic melanoidin pol...
# ...                                                  ...
# 51277  Predation impacts brain allometry in female gu...
# 51278  Evaluating the Impact of Anatomical Partitioni...
# 51279  Genetic drift shapes the evolution of a highly...
# 51280  Epistatic effects between amino acid insertion...
# 51281  Ecology, not host phylogeny, shapes the oral m...
#
#                                                 Abstract  \
# 0      When a solution containing gly-N-pa and imidaz...
# 1      The reactions of glycine with inorganic polyph...
# 2      A reaction which oligomerizes nucleotides unde...
# 3      When solutions of nucleoside 5'-phosphates and...
# 4      One of the major diagenetic pathways of organi...
# ...                                                  ...
# 51277  Cognitive and sensory abilities are vital in a...
# 51278  Morphological data are a fundamental source of...
# 51279  The dynamics of extinction and (re)colonizatio...
# 51280  The recurrent evolution of resistance to cardi...
# 51281  Host-associated microbiomes are essential for ...
#
#                                                      txt
# 0      Prebiotic peptide-formation in the solid state...
# 1      Prebiotic peptide-formation in the solid state...
# 2      The prebiotic synthesis of deoxthymidine oligo...
# 3      Formation of nucleoside 5'-polyphosphates from...
# 4      On the possible role of organic melanoidin pol...
# ...                                                  ...
# 51277  Predation impacts brain allometry in female gu...
# 51278  Evaluating the Impact of Anatomical Partitioni...
# 51279  Genetic drift shapes the evolution of a highly...
# 51280  Epistatic effects between amino acid insertion...
# 51281  Ecology, not host phylogeny, shapes the oral m...
#
# [51282 rows x 8 columns]
